# %% [markdown]
# # Feature-wise analysis (S. 6.2)
#
# Here I examine the conformance of various Ovidian (and non-Ovidian) works to general Ovidian style. It is demonstrated that using the Mahalanobis distance at a 99% confidence level is a fairly reliable indicator of Ovidian vs non-Ovidian authorship, and that none of the _Heroides_ display any statistical reason to reject them in terms of poetic style.

# %%
from mqdq import utils, babble, elegy
from mqdq import line_analyzer as la
from mqdq import mahalanobis as maha

import bs4
import glob

import numpy as np
import pandas as pd
import scipy as sp

from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
vecs = pd.read_csv("elegy_poetic.csv", index_col=0)
corpus = vecs[vecs["LEN"] >= 20].reset_index(drop=True)
# corpus["LEN"] = MinMaxScaler().fit_transform(np.array(corpus["LEN"]).reshape(-1, 1))
corpus = corpus.drop(["LEN"], axis=1)
test_corpus = corpus[corpus.Author != "ps-Ovid"].reset_index(drop=True)
test_corpus
# Out:
#     Author   Work        Poem      H1SP      H2SP      H3SP      H4SP  \
# 0     Ovid    Ep.       Ep. 1  0.086207  0.500000  0.500000  0.448276
# 1     Ovid    Ep.       Ep. 2  0.189189  0.527027  0.581081  0.391892
# 2     Ovid    Ep.       Ep. 3  0.220779  0.493506  0.519481  0.480519
# 3     Ovid    Ep.       Ep. 4  0.102273  0.511364  0.545455  0.465909
# 4     Ovid    Ep.       Ep. 5  0.215190  0.455696  0.632911  0.417722
# ..     ...    ...         ...       ...       ...       ...       ...
# 265   Ovid  Pont.  Pont. 4 12  0.120000  0.520000  0.720000  0.440000
# 266   Ovid  Pont.  Pont. 4 13  0.160000  0.600000  0.680000  0.800000
# 267   Ovid  Pont.  Pont. 4 14  0.129032  0.580645  0.548387  0.645161
# 268   Ovid  Pont.  Pont. 4 15  0.095238  0.619048  0.666667  0.619048
# 269   Ovid  Pont.  Pont. 4 16  0.230769  0.423077  0.769231  0.500000
#
#          H1CF      H2CF      H3CF  ...      P3SC  P4SC      P1WC      P2WC  \
# 0    0.241379  0.706897  0.810345  ...  0.120690   0.0  0.206897  0.068966
# 1    0.283784  0.743243  0.878378  ...  0.148649   0.0  0.202703  0.067568
# 2    0.181818  0.597403  0.818182  ...  0.155844   0.0  0.116883  0.025974
# 3    0.147727  0.659091  0.829545  ...  0.136364   0.0  0.215909  0.045455
# 4    0.164557  0.658228  0.911392  ...  0.164557   0.0  0.202532  0.037975
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 265  0.240000  0.560000  0.920000  ...  0.200000   0.0  0.280000  0.040000
# 266  0.280000  0.720000  0.920000  ...  0.120000   0.0  0.240000  0.080000
# 267  0.096774  0.774194  0.903226  ...  0.387097   0.0  0.193548  0.032258
# 268  0.285714  0.666667  0.714286  ...  0.285714   0.0  0.285714  0.095238
# 269  0.230769  0.692308  0.923077  ...  0.230769   0.0  0.038462  0.076923
#
#          P3WC      P4WC       ELC        RS       LEO      PFSD
# 0    0.396552  1.000000  0.094828  4.393948  0.739842  0.000000
# 1    0.337838  1.000000  0.114865  4.071062  1.027448  0.000000
# 2    0.324675  1.000000  0.090909  3.845700  0.484285  0.000000
# 3    0.329545  1.000000  0.073864  3.822098  0.893575  0.000000
# 4    0.341772  1.000000  0.056962  3.727347  0.713715  0.000000
# ..        ...       ...       ...       ...       ...       ...
# 265  0.280000  1.000000  0.100000  3.073075  0.615696  0.000000
# 266  0.360000  0.880000  0.100000  5.954342  1.723439  0.775629
# 267  0.193548  0.903226  0.064516  3.314164  1.155196  0.591300
# 268  0.333333  0.952381  0.119048  3.695211  0.919168  0.425918
# 269  0.346154  1.000000  0.076923  3.567146  0.135079  0.000000
#
# [270 rows x 45 columns]

# %%
problems = corpus[corpus.Author == "ps-Ovid"].reset_index(drop=True)
problems
# Out:
#     Author        Work          Poem      H1SP      H2SP      H3SP      H4SP  \
# 0  ps-Ovid         Nux           Nux  0.153846  0.450549  0.626374  0.626374
# 1  ps-Ovid  Medicamina    Medicamina  0.280000  0.480000  0.520000  0.540000
# 2  ps-Ovid  Consolatio  Consolatio 1  0.240506  0.481013  0.645570  0.531646
# 3  ps-Ovid  Consolatio  Consolatio 2  0.253165  0.556962  0.556962  0.493671
# 4  ps-Ovid  Consolatio  Consolatio 3  0.329114  0.506329  0.658228  0.582278
# 5  ps-Ovid        Ibis        Ibis 1  0.156250  0.718750  0.562500  0.593750
# 6  ps-Ovid        Ibis        Ibis 2  0.160000  0.530000  0.620000  0.440000
# 7  ps-Ovid        Ibis        Ibis 3  0.190000  0.450000  0.730000  0.550000
# 8  ps-Ovid        Ibis        Ibis 4  0.123596  0.438202  0.617978  0.528090
#
#        H1CF      H2CF      H3CF  ...      P3SC  P4SC      P1WC      P2WC  \
# 0  0.175824  0.604396  0.868132  ...  0.164835   0.0  0.197802  0.043956
# 1  0.180000  0.620000  0.880000  ...  0.100000   0.0  0.200000  0.040000
# 2  0.164557  0.582278  0.924051  ...  0.265823   0.0  0.088608  0.037975
# 3  0.240506  0.696203  0.810127  ...  0.151899   0.0  0.088608  0.025316
# 4  0.291139  0.594937  0.772152  ...  0.202532   0.0  0.151899  0.037975
# 5  0.156250  0.562500  0.906250  ...  0.218750   0.0  0.187500  0.000000
# 6  0.100000  0.580000  0.960000  ...  0.160000   0.0  0.230000  0.060000
# 7  0.180000  0.730000  0.950000  ...  0.170000   0.0  0.240000  0.050000
# 8  0.179775  0.685393  0.988764  ...  0.382022   0.0  0.258427  0.056180
#
#        P3WC      P4WC       ELC        RS       LEO      PFSD
# 0  0.285714  1.000000  0.082418  3.095360  0.524756  0.000000
# 1  0.300000  1.000000  0.080000  4.901116  0.909967  0.000000
# 2  0.278481  1.000000  0.246835  4.619877  0.606677  0.000000
# 3  0.240506  1.000000  0.278481  3.608988  0.824542  0.000000
# 4  0.240506  0.987342  0.202532  4.590044  1.062847  0.223589
# 5  0.218750  1.000000  0.109375  3.986751  1.053890  0.000000
# 6  0.360000  1.000000  0.130000  4.683774  0.994626  0.000000
# 7  0.260000  1.000000  0.060000  4.070276  0.787213  0.000000
# 8  0.213483  0.977528  0.033708  4.358413  0.791811  0.469227
#
# [9 rows x 45 columns]

# %%
corpus_dict = dict(
    corpus.apply(
        lambda r: [r.Poem, corpus[corpus.Poem == r.Poem].iloc[:, 3:]],
        axis=1,
    ).to_numpy()
)

# %%
ovid_dist = (
    test_corpus[test_corpus.Author == "Ovid"]
    .drop(["Author", "Work", "Poem"], axis=1)
    .reset_index(drop=True)
)
ovid_late = (
    test_corpus[test_corpus.Work.isin(["Trist.", "Pont."])]
    .drop(["Author", "Work", "Poem"], axis=1)
    .reset_index(drop=True)
)
ovid_early = (
    test_corpus[test_corpus.Work.isin(["Ep.", "Am."])]
    .drop(["Author", "Work", "Poem"], axis=1)
    .reset_index(drop=True)
)

# %%
maha.compare_elegy(corpus_dict["Nux"], ovid_late, lim=10, shrinkage=0.05)
# Out:
# ------------------------------------
#   M-dist 27.84,  p-value: 0.9419
#   Feat 	 Score 	   Samp      Dist
# ------------------------------------
# P1DI     3.61     40.66%    53.19%
# P3SC     3.52     16.48%    26.38%
# H1SC     3.00     58.24%    49.00%
# H4SP     2.95     62.64%    57.19%
# H4DI     2.05     62.64%    53.78%
# P2SP     1.95     71.43%    63.11%
# PFSD     1.75      0.00      0.16
# H2SP     1.54     45.05%    52.72%
#  LEO     1.17      0.52      0.82
# P1SC     1.07     34.07%    40.05%
#   [truncating at limit = 10]
# ------------------------------------

# %%
maha.compare_elegy(corpus_dict["Nux"], ovid_dist, lim=10, shrinkage=0.0)
# Out:
# ------------------------------------
#   M-dist 18.85,  p-value: 0.9988
#   Feat 	 Score 	   Samp      Dist
# ------------------------------------
#   RS     3.69      3.10      3.98
# P1DI     3.48     40.66%    52.04%
# H4SP     2.20     62.64%    53.93%
# P2SP     1.88     71.43%    61.36%
# H4DI     1.85     62.64%    51.38%
# PFSD     1.28      0.00      0.08
# H1SC     1.17     58.24%    49.26%
# P3SC     1.02     16.48%    22.00%
# H3WC     0.99      7.69%     5.39%
# H3CF     0.78     86.81%    89.50%
#   [truncating at limit = 10]
# ------------------------------------

# %%
maha.compare_elegy(corpus_dict["Consolatio 1"], ovid_dist, lim=10, shrinkage=0.0)
# Out:
# ------------------------------------
#   M-dist 56.07,  p-value: 0.0586
#   Feat 	 Score 	   Samp      Dist
# ------------------------------------
#  ELC    20.84      0.25      0.09
# H4WC     9.92     13.92%     5.41%
# H2WC     6.45     24.05%    10.07%
# P2CF     4.13     60.76%    73.56%
# P3CF     2.41     21.52%    13.34%
# H3CF     2.37     92.41%    89.50%
# H3SC     2.27     93.67%    94.40%
#   RS     2.14      4.62      3.98
# H2SC     2.01     39.24%    58.88%
# P4CF     1.91      0.00%     0.75%
#   [truncating at limit = 10]
# ------------------------------------

# %%
maha.compare_elegy(corpus_dict["Consolatio 3"], ovid_dist, lim=10, shrinkage=0.0)
# Out:
# ------------------------------------
#   M-dist 81.24,  p-value: 0.0002
#   Feat 	 Score 	   Samp      Dist
# ------------------------------------
# H3SC   134.15     79.75%    94.40%
# H3CF     9.68     77.22%    89.50%
# PFSD     8.53      0.22      0.08
#  ELC     7.93      0.20      0.09
# H1SP     6.25     32.91%    15.72%
#   RS     2.60      4.59      3.98
# H1DI     2.28     44.30%    59.69%
# H2CF     2.12     59.49%    64.95%
# H1CF     2.04     29.11%    15.33%
#  LEO     1.75      1.06      0.79
#   [truncating at limit = 10]
# ------------------------------------

# %%
maha.compare_elegy(corpus_dict["Ibis 4"], ovid_dist, lim=10, shrinkage=0.0)
# Out:
# ------------------------------------
#   M-dist 88.52,  p-value: 0.0000
#   Feat 	 Score 	   Samp      Dist
# ------------------------------------
# PFSD    46.84      0.47      0.08
# H3CF    10.72     98.88%    89.50%
# H2SC    10.52     41.57%    58.88%
# P3SC     8.66     38.20%    22.00%
# H1DI     5.93     46.07%    59.69%
# H1SC     5.46     30.34%    49.26%
# P2SC     4.06     52.81%    65.21%
# H4WC     3.67     11.24%     5.41%
# P1CF     3.43     15.73%    26.87%
# P1WC     2.68     25.84%    18.68%
#   [truncating at limit = 10]
# ------------------------------------

# %%
from scipy.stats import chi2

v, m, p = maha.explain(corpus_dict["Ibis 4"], ovid_dist, shrinkage=0.0)
biggest = sorted(v.to_numpy()[0])[-1]
print(f"Trying with M-dist {m - biggest:.2f} instead of {m:.2f}")
new_p = 1 - chi2.cdf(m - biggest, len(corpus_dict["Ibis 4"].columns) - 1)
print(f"Counterfactual p-val: {new_p:.2f}")
# Out:
# Trying with M-dist 41.67 instead of 88.52
# Counterfactual p-val: 0.44

# %% [markdown]
# # A note on the Mahalanobis distance
#
# The redoutable wikipedia has a [quick primer](https://en.wikipedia.org/wiki/Mahalanobis_distance) on the Mahalanobis distance, but the intuition is not too difficult (at least for those with some undergraduate statistics!). It is more or less like the euclidean distance, except it takes into account correlations between features. For _m_ observations in an _n_ dimensional feature space, the _covariance matrix_ is an _n_ x _n_ matrix that describes all the pairwise correlations between the features. The inverse of this matrix is then used to "correct" for those correlations. Because of the way the vectors are multiplied, it is also possible to save the product vector to see exactly which features contribute the most distance to the overall score, which is a very useful tool for interpretability. Note that in all cases below I actually measure the _squared_ M-distance. This has no effect on any comparisons, but the squared M-distance is chi-square distributed, which makes it easy to calculate a _P_-value for any distance.

# %% [markdown]
# # Deconstructed Mahalanobis distance of _Ep._ 15 from Ovidian tendency
#
# There are very few features that differ significantly from typical Ovidian style. The length shows up as a difference (all of the _Heroides_ are longer than most of Ovid's short elegy), as do some minor differences in the caesurae in the third and fourth feet of the hexameter, but that's about it. As for the _P_-value, there is clearly no statistical reason to reject the null hypothesis (ie no reason to reject the idea that it was written by Ovid).

# %% [markdown]
# # The method works, in general
#
# A random poem by Propertius is, unsurprisingly, very not-Ovidian. Here I picked Propertius 3.10 more or less at random, to demonstrate that non-Ovidian works are usually easily detectable as non-Ovidian style.
#
# The biggest differences (after correcting for feature covariance)
# - Prop 3.10 is much more spondaic in the first and second feet
#   of the hexameter than the Ovidian norm
# - Prop. 3.10 is less likely to have a diaeresis in H1 (which happens when the
#   first foot is a disyllable)
# - the poem has much more elision than is typical for Ovid
# - the poem has no ictus conflicts after the caesura in the pentameter, whereas
#   Ovid apparently does this one line in seven or eight (although Prop 3.5 is only 32 lines)

# %% [markdown]
# # Testing the accuracy
#
# _Heroides_ 15 reads as Ovidian, and Propertius 3.10 reads as non-Ovidian, but it is worth checking the general accuracy. Here I just look quickly at the number of false positives and negatives when working at the 99% confidence level. It seems that the method is not actually 99% accurate (which is not all that surprising) but nevertheless it does a very good job. 5 of 102 non-Ovidian works might be mistaken for Ovid (about 5%), and just 14 of 164 Ovidian works are sufficiently unusual as to read as non-Ovidian (2.4%), almost all of which are later works.

# %%
# A quick function we can apply to the dataframe to add the M-dist
# and p-value (compared to Ovidian style) for every work in the corpus


def maha_from_ovid(row, dist, shrinkage):
    _, m, p = maha.explain(
        corpus[corpus.Poem == row.Poem].iloc[:, 3:],
        dist,
        shrinkage,
    )
    return pd.Series([m, p])

# %%
dist_vecs = corpus.apply(maha_from_ovid, args=(ovid_dist, 0.0), axis=1)

# %%
dists = corpus.copy()
dists.insert(3, "OvDist", dist_vecs[0])
dists.insert(4, "pval", dist_vecs[1])

# %%
# false positives - non-Ovidian detected as Ovid

dists[~dists.Author.isin(["Ovid", "ps-Ovid"])].sort_values(by="OvDist").query(
    "pval > 0.01"
)
# Out:
#          Author   Work        Poem     OvDist      pval      H1SP      H2SP  \
# 218  Propertius  Prop.  Prop. 4 11  37.896400  0.609343  0.313725  0.588235
# 213  Propertius  Prop.   Prop. 4 6  49.251443  0.176459  0.279070  0.627907
# 207  Propertius  Prop.  Prop. 3 24  56.335577  0.055833  0.315789  0.473684
# 211  Propertius  Prop.   Prop. 4 4  63.237763  0.014431  0.319149  0.553191
# 122    Tibullus   Tib.    Tib. 1 4  64.360000  0.011362  0.309524  0.452381
#
#          H3SP      H4SP      H1CF  ...      P3SC  P4SC      P1WC      P2WC  \
# 218  0.627451  0.666667  0.313725  ...  0.196078   0.0  0.254902  0.019608
# 213  0.720930  0.604651  0.139535  ...  0.232558   0.0  0.279070  0.093023
# 207  0.578947  0.526316  0.210526  ...  0.263158   0.0  0.157895  0.000000
# 211  0.595745  0.638298  0.276596  ...  0.063830   0.0  0.063830  0.085106
# 122  0.666667  0.666667  0.214286  ...  0.285714   0.0  0.142857  0.023810
#
#          P3WC      P4WC       ELC        RS       LEO      PFSD
# 218  0.294118  1.000000  0.127451  4.526738  1.394520  0.000000
# 213  0.279070  1.000000  0.162791  4.538231  1.191339  0.000000
# 207  0.421053  1.000000  0.210526  4.517161  1.053250  0.000000
# 211  0.404255  0.978723  0.234043  3.796900  1.176762  0.288610
# 122  0.214286  0.952381  0.059524  4.867841  0.867571  0.543462
#
# [5 rows x 47 columns]

# %%
dists[dists.Author == "ps-Ovid"].sort_values(by="OvDist")
# Out:
#       Author        Work          Poem     OvDist      pval      H1SP  \
# 276  ps-Ovid        Ibis        Ibis 2  13.835231  0.999978  0.160000
# 270  ps-Ovid         Nux           Nux  18.848283  0.998812  0.153846
# 271  ps-Ovid  Medicamina    Medicamina  19.109011  0.998604  0.280000
# 277  ps-Ovid        Ibis        Ibis 3  26.882836  0.956321  0.190000
# 275  ps-Ovid        Ibis        Ibis 1  46.243903  0.264658  0.156250
# 272  ps-Ovid  Consolatio  Consolatio 1  56.065557  0.058610  0.240506
# 273  ps-Ovid  Consolatio  Consolatio 2  60.273737  0.026468  0.253165
# 274  ps-Ovid  Consolatio  Consolatio 3  81.237912  0.000184  0.329114
# 278  ps-Ovid        Ibis        Ibis 4  88.516539  0.000024  0.123596
#
#          H2SP      H3SP      H4SP      H1CF  ...      P3SC  P4SC      P1WC  \
# 276  0.530000  0.620000  0.440000  0.100000  ...  0.160000   0.0  0.230000
# 270  0.450549  0.626374  0.626374  0.175824  ...  0.164835   0.0  0.197802
# 271  0.480000  0.520000  0.540000  0.180000  ...  0.100000   0.0  0.200000
# 277  0.450000  0.730000  0.550000  0.180000  ...  0.170000   0.0  0.240000
# 275  0.718750  0.562500  0.593750  0.156250  ...  0.218750   0.0  0.187500
# 272  0.481013  0.645570  0.531646  0.164557  ...  0.265823   0.0  0.088608
# 273  0.556962  0.556962  0.493671  0.240506  ...  0.151899   0.0  0.088608
# 274  0.506329  0.658228  0.582278  0.291139  ...  0.202532   0.0  0.151899
# 278  0.438202  0.617978  0.528090  0.179775  ...  0.382022   0.0  0.258427
#
#          P2WC      P3WC      P4WC       ELC        RS       LEO      PFSD
# 276  0.060000  0.360000  1.000000  0.130000  4.683774  0.994626  0.000000
# 270  0.043956  0.285714  1.000000  0.082418  3.095360  0.524756  0.000000
# 271  0.040000  0.300000  1.000000  0.080000  4.901116  0.909967  0.000000
# 277  0.050000  0.260000  1.000000  0.060000  4.070276  0.787213  0.000000
# 275  0.000000  0.218750  1.000000  0.109375  3.986751  1.053890  0.000000
# 272  0.037975  0.278481  1.000000  0.246835  4.619877  0.606677  0.000000
# 273  0.025316  0.240506  1.000000  0.278481  3.608988  0.824542  0.000000
# 274  0.037975  0.240506  0.987342  0.202532  4.590044  1.062847  0.223589
# 278  0.056180  0.213483  0.977528  0.033708  4.358413  0.791811  0.469227
#
# [9 rows x 47 columns]

# %%
# false negatives - Ovidian detected as non-Ovidian

dists[dists.Author == "Ovid"].sort_values(by="OvDist").query("pval < 0.01")
# Out:
#     Author   Work        Poem      OvDist          pval      H1SP      H2SP  \
# 45    Ovid    Tr.    Tr. 3 13   65.035165  9.816442e-03  0.071429  0.428571
# 48    Ovid    Tr.     Tr. 4 2   66.528854  7.059382e-03  0.216216  0.540541
# 81    Ovid    Am.    Am. 1 11   67.797081  5.300980e-03  0.142857  0.428571
# 40    Ovid    Tr.     Tr. 3 8   70.214800  3.021778e-03  0.095238  0.523810
# 118   Ovid    Am.    Am. 3 15   71.322876  2.319912e-03  0.200000  0.500000
# 92    Ovid    Am.     Am. 2 8   73.623514  1.322948e-03  0.214286  0.642857
# 266   Ovid  Pont.  Pont. 4 13   77.271169  5.249784e-04  0.160000  0.600000
# 250   Ovid  Pont.   Pont. 3 6   84.061254  8.500692e-05  0.166667  0.433333
# 69    Ovid    Tr.    Tr. 5 13   84.701512  7.115578e-05  0.000000  0.588235
# 24    Ovid    Tr.     Tr. 1 4   86.061090  4.861191e-05  0.071429  0.285714
# 264   Ovid  Pont.  Pont. 4 11   86.221685  4.645902e-05  0.181818  0.363636
# 97    Ovid    Am.    Am. 2 13   91.461109  1.026019e-05  0.000000  0.571429
# 63    Ovid    Tr.     Tr. 5 7  100.343321  6.956219e-07  0.058824  0.794118
# 229   Ovid  Pont.   Pont. 1 6  123.856645  2.976172e-10  0.259259  0.555556
#
#          H3SP      H4SP      H1CF  ...      P3SC      P4SC      P1WC  \
# 45   0.571429  0.357143  0.000000  ...  0.142857  0.000000  0.000000
# 48   0.702703  0.702703  0.189189  ...  0.324324  0.000000  0.162162
# 81   0.642857  0.571429  0.214286  ...  0.071429  0.000000  0.214286
# 40   0.666667  0.666667  0.095238  ...  0.285714  0.000000  0.190476
# 118  0.400000  0.600000  0.200000  ...  0.100000  0.000000  0.000000
# 92   0.428571  0.785714  0.214286  ...  0.214286  0.000000  0.142857
# 266  0.680000  0.800000  0.280000  ...  0.120000  0.000000  0.240000
# 250  0.666667  0.533333  0.233333  ...  0.200000  0.033333  0.200000
# 69   0.588235  0.411765  0.058824  ...  0.411765  0.058824  0.294118
# 24   0.857143  0.571429  0.071429  ...  0.285714  0.000000  0.071429
# 264  0.909091  0.454545  0.363636  ...  0.636364  0.000000  0.000000
# 97   0.571429  0.428571  0.142857  ...  0.214286  0.000000  0.071429
# 63   0.617647  0.705882  0.117647  ...  0.205882  0.000000  0.235294
# 229  0.407407  0.703704  0.148148  ...  0.222222  0.037037  0.259259
#
#          P2WC      P3WC      P4WC       ELC        RS       LEO      PFSD
# 45   0.071429  0.500000  1.000000  0.000000  4.517619  0.263198  0.000000
# 48   0.081081  0.243243  0.972973  0.135135  3.803756  0.986833  0.000000
# 81   0.000000  0.500000  1.000000  0.285714  4.260925  0.588626  0.000000
# 40   0.047619  0.380952  1.000000  0.071429  2.727267  0.176037  0.000000
# 118  0.000000  0.100000  1.000000  0.150000  3.196094  0.965258  0.000000
# 92   0.000000  0.428571  1.000000  0.107143  4.158458  1.479839  0.000000
# 266  0.080000  0.360000  0.880000  0.100000  5.954342  1.723439  0.775629
# 250  0.033333  0.333333  0.966667  0.083333  4.160358  1.065353  0.179505
# 69   0.000000  0.176471  0.941176  0.029412  3.437513  0.824276  0.000000
# 24   0.214286  0.285714  0.928571  0.035714  3.982128  1.291192  0.515079
# 264  0.000000  0.090909  1.000000  0.181818  4.077262  0.303296  0.000000
# 97   0.285714  0.214286  1.000000  0.107143  3.399374  0.250861  0.000000
# 63   0.029412  0.323529  1.000000  0.132353  4.545058  0.966493  0.168958
# 229  0.037037  0.333333  0.962963  0.074074  3.862795  0.764844  0.188853
#
# [14 rows x 47 columns]

# %% [markdown]
# # All of the _Heroides_ sorted by M-distance (larger scores less like 'typical' Ovidian style
#
# Note that even the most different are nowhere near different enough to be in statistical doubt. Of course this doesn't prove that they are Ovidian, but it does show that they conform superbly well with every feature that was measured.

# %%
dists[dists.Work == "Ep."].sort_values(by="OvDist")
# Out:
#    Author Work    Poem     OvDist      pval      H1SP      H2SP      H3SP  \
# 4    Ovid  Ep.   Ep. 5  12.441285  0.999995  0.215190  0.455696  0.632911
# 3    Ovid  Ep.   Ep. 4  15.707609  0.999878  0.102273  0.511364  0.545455
# 20   Ovid  Ep.  Ep. 21  16.409644  0.999785  0.211382  0.512195  0.682927
# 15   Ovid  Ep.  Ep. 16  17.353912  0.999563  0.085106  0.611702  0.659574
# 12   Ovid  Ep.  Ep. 13  17.822620  0.999393  0.172840  0.493827  0.543210
# 19   Ovid  Ep.  Ep. 20  17.896850  0.999361  0.159664  0.529412  0.672269
# 5    Ovid  Ep.   Ep. 6  18.167086  0.999234  0.168675  0.445783  0.554217
# 18   Ovid  Ep.  Ep. 19  18.809297  0.998840  0.104762  0.514286  0.647619
# 17   Ovid  Ep.  Ep. 18  23.141463  0.988925  0.128440  0.633028  0.568807
# 11   Ovid  Ep.  Ep. 12  23.634200  0.986380  0.207547  0.452830  0.632075
# 10   Ovid  Ep.  Ep. 11  23.829999  0.985249  0.078125  0.562500  0.500000
# 2    Ovid  Ep.   Ep. 3  23.886237  0.984910  0.220779  0.493506  0.519481
# 16   Ovid  Ep.  Ep. 17  25.086615  0.976128  0.172932  0.503759  0.669173
# 14   Ovid  Ep.  Ep. 15  29.239758  0.915176  0.275229  0.458716  0.633028
# 6    Ovid  Ep.   Ep. 7  29.572948  0.907800  0.091837  0.500000  0.663265
# 7    Ovid  Ep.   Ep. 8  29.580060  0.907639  0.186441  0.423729  0.559322
# 1    Ovid  Ep.   Ep. 2  29.922289  0.899636  0.189189  0.527027  0.581081
# 9    Ovid  Ep.  Ep. 10  30.101599  0.895272  0.253333  0.680000  0.693333
# 0    Ovid  Ep.   Ep. 1  30.575274  0.883182  0.086207  0.500000  0.500000
# 8    Ovid  Ep.   Ep. 9  31.875037  0.845849  0.243902  0.463415  0.682927
# 13   Ovid  Ep.  Ep. 14  35.645508  0.707009  0.196970  0.424242  0.469697
#
#         H4SP      H1CF  ...      P3SC      P4SC      P1WC      P2WC      P3WC  \
# 4   0.417722  0.164557  ...  0.164557  0.000000  0.202532  0.037975  0.341772
# 3   0.465909  0.147727  ...  0.136364  0.000000  0.215909  0.045455  0.329545
# 20  0.552846  0.219512  ...  0.252033  0.000000  0.243902  0.024390  0.300813
# 15  0.558511  0.143617  ...  0.228723  0.000000  0.212766  0.047872  0.292553
# 12  0.518519  0.160494  ...  0.160494  0.000000  0.259259  0.049383  0.345679
# 19  0.470588  0.201681  ...  0.344538  0.008403  0.142857  0.025210  0.302521
# 5   0.445783  0.180723  ...  0.216867  0.000000  0.228916  0.036145  0.325301
# 18  0.514286  0.171429  ...  0.180952  0.000000  0.161905  0.028571  0.342857
# 17  0.412844  0.211009  ...  0.412844  0.009174  0.220183  0.036697  0.174312
# 11  0.433962  0.113208  ...  0.160377  0.000000  0.160377  0.018868  0.311321
# 10  0.562500  0.140625  ...  0.140625  0.000000  0.140625  0.046875  0.390625
# 2   0.480519  0.181818  ...  0.155844  0.000000  0.116883  0.025974  0.324675
# 16  0.503759  0.165414  ...  0.300752  0.000000  0.165414  0.045113  0.255639
# 14  0.495413  0.155963  ...  0.155963  0.000000  0.174312  0.055046  0.385321
# 6   0.469388  0.132653  ...  0.112245  0.000000  0.193878  0.000000  0.336735
# 7   0.406780  0.135593  ...  0.220339  0.000000  0.186441  0.000000  0.389831
# 1   0.391892  0.283784  ...  0.148649  0.000000  0.202703  0.067568  0.337838
# 9   0.560000  0.226667  ...  0.200000  0.000000  0.173333  0.026667  0.386667
# 0   0.448276  0.241379  ...  0.120690  0.000000  0.206897  0.068966  0.396552
# 8   0.487805  0.146341  ...  0.158537  0.000000  0.109756  0.012195  0.378049
# 13  0.409091  0.257576  ...  0.287879  0.015152  0.181818  0.030303  0.303030
#
#         P4WC       ELC        RS       LEO      PFSD
# 4   1.000000  0.056962  3.727347  0.713715  0.000000
# 3   1.000000  0.073864  3.822098  0.893575  0.000000
# 20  1.000000  0.065041  4.251277  0.895832  0.000000
# 15  0.994681  0.090426  4.589444  0.670450  0.218215
# 12  1.000000  0.098765  4.916439  0.755515  0.000000
# 19  0.991597  0.050420  3.802721  0.516711  0.000000
# 5   1.000000  0.090361  4.489172  0.689778  0.000000
# 18  0.990476  0.071429  4.116780  0.799599  0.194248
# 17  0.990826  0.064220  3.807675  0.724245  0.000000
# 11  1.000000  0.141509  3.521203  0.608035  0.000000
# 10  1.000000  0.109375  4.608592  0.868259  0.000000
# 2   1.000000  0.090909  3.845700  0.484285  0.000000
# 16  0.992481  0.045113  3.963750  0.699332  0.259153
# 14  1.000000  0.128440  3.004543  0.633201  0.000000
# 6   1.000000  0.153061  3.974571  0.819895  0.000000
# 7   1.000000  0.127119  4.683895  0.791726  0.000000
# 1   1.000000  0.114865  4.071062  1.027448  0.000000
# 9   0.986667  0.093333  4.185137  0.915005  0.000000
# 0   1.000000  0.094828  4.393948  0.739842  0.000000
# 8   1.000000  0.109756  3.276667  0.491081  0.000000
# 13  0.984848  0.060606  3.926984  0.805699  0.122155
#
# [21 rows x 47 columns]
